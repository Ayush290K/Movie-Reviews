# %%
from nltk.corpus import movie_reviews

# %%
import nltk
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# True

# %%
movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %%
x = movie_reviews.fileids('neg')
x[0:10]
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt',
#  'neg/cv005_29357.txt',
#  'neg/cv006_17022.txt',
#  'neg/cv007_4992.txt',
#  'neg/cv008_29326.txt',
#  'neg/cv009_29417.txt']

# %%
y = movie_reviews.fileids('pos')
y[0:10]
# Out:
# ['pos/cv000_29590.txt',
#  'pos/cv001_18431.txt',
#  'pos/cv002_15918.txt',
#  'pos/cv003_11664.txt',
#  'pos/cv004_11636.txt',
#  'pos/cv005_29443.txt',
#  'pos/cv006_15448.txt',
#  'pos/cv007_4968.txt',
#  'pos/cv008_29435.txt',
#  'pos/cv009_29592.txt']

# %%
document = []
for category in movie_reviews.categories():
  for fileid in movie_reviews.fileids(category):
    document.append((movie_reviews.words(fileid), category))
document[0:10]
# Out:
# [(['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...], 'neg'),
#  (['the', 'happy', 'bastard', "'", 's', 'quick', 'movie', ...], 'neg'),
#  (['it', 'is', 'movies', 'like', 'these', 'that', 'make', ...], 'neg'),
#  (['"', 'quest', 'for', 'camelot', '"', 'is', 'warner', ...], 'neg'),
#  (['synopsis', ':', 'a', 'mentally', 'unstable', 'man', ...], 'neg'),
#  (['capsule', ':', 'in', '2176', 'on', 'the', 'planet', ...], 'neg'),
#  (['so', 'ask', 'yourself', 'what', '"', '8mm', '"', '(', ...], 'neg'),
#  (['that', "'", 's', 'exactly', 'how', 'long', 'the', ...], 'neg'),
#  (['call', 'it', 'a', 'road', 'trip', 'for', 'the', ...], 'neg'),
#  (['plot', ':', 'a', 'young', 'french', 'boy', 'sees', ...], 'neg')]

# %%
import random
random.shuffle(document)
document[0:10]
# Out:
# [(['in', 'intolerance', ',', 'd', '.', 'w', '.', ...], 'pos'),
#  (['plot', ':', 'a', 'rich', 'psychiatrist', 'with', 'a', ...], 'neg'),
#  (['expand', 'the', 'final', 'fifteen', 'minutes', 'of', ...], 'pos'),
#  (['"', 'last', 'night', '"', 'could', 'have', 'an', '"', ...], 'pos'),
#  (['jarvis', 'cocker', 'of', 'pulp', 'once', 'said', ...], 'pos'),
#  (['an', 'astonishingly', 'difficult', 'movie', 'to', ...], 'pos'),
#  (['frequency', 'n', '.', ',', 'the', 'number', 'of', ...], 'pos'),
#  (['don', "'", 't', 'let', 'the', 'following', 'quirks', ...], 'pos'),
#  (['bruce', 'willis', 'is', 'a', 'type', '-', 'casted', ...], 'pos'),
#  (['perhaps', 'the', 'most', 'dramatic', 'changes', 'in', ...], 'pos')]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
from nltk.corpus import wordnet
def get_simple_pos(tag):

    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
from nltk import pos_tag

# %%
from nltk.corpus import stopwords
import string
stops = set(stopwords.words('english'))
punctuations = list(string.punctuation)
stops.update(punctuations)
stops, string.punctuation
# Out:
# ({'!',
#   '"',
#   '#',
#   '$',
#   '%',
#   '&',
#   "'",
#   '(',
#   ')',
#   '*',
#   '+',
#   ',',
#   '-',
#   '.',
#   '/',
#   ':',
#   ';',
#   '<',
#   '=',
#   '>',
#   '?',
#   '@',
#   '[',
#   '\\',
#   ']',
#   '^',
#   '_',
#   '`',
#   'a',
#   'about',
#   'above',
#   'after',
#   'again',
#   'against',
#   'ain',
#   'all',
#   'am',
#   'an',
#   'and',
#   'any',
#   'are',
#   'aren',
#   "aren't",
#   'as',
#   'at',
#   'be',
#   'because',
#   'been',
#   'before',
#   'being',
#   'below',
#   'between',
#   'both',
#   'but',
#   'by',
#   'can',
#   'couldn',
#   "couldn't",
#   'd',
#   'did',
#   'didn',
#   "didn't",
#   'do',
#   'does',
#   'doesn',
#   "doesn't",
#   'doing',
#   'don',
#   "don't",
#   'down',
#   'during',
#   'each',
#   'few',
#   'for',
#   'from',
#   'further',
#   'had',
#   'hadn',
#   "hadn't",
#   'has',
#   'hasn',
#   "hasn't",
#   'have',
#   'haven',
#   "haven't",
#   'having',
#   'he',
#   'her',
#   'here',
# ...

# %%
def clean_reviews(words):
  clean_words = []
  for w in words:
    if w.lower() not in stops:
      pos = pos_tag([w])
      new_words = lemmatizer.lemmatize(w, get_simple_pos(pos[0][1]))
      clean_words.append(new_words.lower())
  return clean_words

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
documents = [(clean_reviews(document), category) for document, category in document]
documents[0]
# Out:
# (['intolerance',
#   'w',
#   'griffith',
#   'told',
#   'four',
#   'different',
#   'historical',
#   'story',
#   'time',
#   'cut',
#   'one',
#   'story',
#   'build',
#   'fast',
#   'pace',
#   'climax',
#   'magnolia',
#   'paul',
#   'thomas',
#   'anderson',
#   'tell',
#   'several',
#   'story',
#   'tangentially',
#   'connect',
#   'others',
#   'yet',
#   'story',
#   'go',
#   'independent',
#   'strange',
#   'story',
#   'synchronize',
#   'story',
#   'build',
#   'tense',
#   'moment',
#   'appear',
#   'intend',
#   'tense',
#   'moment',
#   'let',
#   'tension',
#   'dissolve',
#   'tension',
#   'dissipates',
#   'one',
#   'character',
#   'start',
#   'sing',
#   'song',
#   'plotline',
#   'major',
#   'character',
#   'sing',
#   'along',
#   'even',
#   'though',
#   'scene',
#   'toward',
#   'end',
#   'story',
#   'build',
#   'tense',
#   'moment',
#   'almost',
#   'character',
#   'somehow',
#   'psychically',
#   'link',
#   'creates',
# ...

# %%
training_documents = documents[0:1500]
testing_documents = documents[1500:]

# %%
all_words = []
for doc in training_documents:
    all_words += doc[0]

# %%
freq = nltk.FreqDist(all_words)
common = freq.most_common(3000)
features = [i[0] for i in common]

# %%
features
# Out:
# ['film',
#  'movie',
#  'one',
#  'make',
#  'like',
#  'character',
#  'get',
#  'see',
#  'go',
#  'time',
#  'well',
#  'scene',
#  'even',
#  'good',
#  'story',
#  'take',
#  'much',
#  'would',
#  'life',
#  'also',
#  'come',
#  'give',
#  'bad',
#  'seem',
#  'two',
#  'end',
#  'way',
#  'look',
#  'know',
#  'first',
#  '--',
#  'work',
#  'year',
#  'thing',
#  'play',
#  'plot',
#  'say',
#  'little',
#  'really',
#  'show',
#  'people',
#  'could',
#  'best',
#  'man',
#  'love',
#  'star',
#  'try',
#  'director',
#  'great',
#  'never',
#  'performance',
#  'actor',
#  'new',
#  'many',
#  'action',
#  'watch',
#  'big',
#  'want',
#  'u',
#  'find',
#  'role',
#  'another',
#  'think',
#  'act',
#  'still',
#  'audience',
#  'turn',
#  'back',
#  'world',
#  'set',
#  'however',
#  'day',
#  'something',
#  'old',
#  'though',
#  'use',
#  'part',
#  'begin',
#  'cast',
#  'every',
#  'comedy',
#  'feel',
#  'interest',
#  'around',
#  'point',
#  'last',
#  'real',
# ...

# %%
def get_feature_dict(words):
    current_features = {}
    words_set = set(words)
    for w in features:
        current_features[w] = w in words_set
    return current_features

# %%
output = get_feature_dict(training_documents[0][0])
output
# Out:
# {'film': True,
#  'movie': False,
#  'one': True,
#  'make': True,
#  'like': True,
#  'character': True,
#  'get': True,
#  'see': True,
#  'go': True,
#  'time': True,
#  'well': True,
#  'scene': True,
#  'even': True,
#  'good': False,
#  'story': True,
#  'take': False,
#  'much': True,
#  'would': True,
#  'life': False,
#  'also': False,
#  'come': True,
#  'give': True,
#  'bad': False,
#  'seem': True,
#  'two': True,
#  'end': True,
#  'way': True,
#  'look': True,
#  'know': True,
#  'first': True,
#  '--': False,
#  'work': False,
#  'year': False,
#  'thing': False,
#  'play': False,
#  'plot': False,
#  'say': True,
#  'little': True,
#  'really': True,
#  'show': True,
#  'people': True,
#  'could': False,
#  'best': False,
#  'man': True,
#  'love': False,
#  'star': False,
#  'try': False,
#  'director': False,
#  'great': True,
#  'never': False,
#  'performance': True,
#  'actor': True,
#  'new': False,
#  'many': True,
#  'action': False,
#  'watch': False,
# ...

# %%
training_data = [(get_feature_dict(doc), category) for doc, category in training_documents]
testing_data = [(get_feature_dict(doc), category) for doc, category in training_documents]

# %%
training_data[0]
# Out:
# ({'film': True,
#   'movie': False,
#   'one': True,
#   'make': True,
#   'like': True,
#   'character': True,
#   'get': True,
#   'see': True,
#   'go': True,
#   'time': True,
#   'well': True,
#   'scene': True,
#   'even': True,
#   'good': False,
#   'story': True,
#   'take': False,
#   'much': True,
#   'would': True,
#   'life': False,
#   'also': False,
#   'come': True,
#   'give': True,
#   'bad': False,
#   'seem': True,
#   'two': True,
#   'end': True,
#   'way': True,
#   'look': True,
#   'know': True,
#   'first': True,
#   '--': False,
#   'work': False,
#   'year': False,
#   'thing': False,
#   'play': False,
#   'plot': False,
#   'say': True,
#   'little': True,
#   'really': True,
#   'show': True,
#   'people': True,
#   'could': False,
#   'best': False,
#   'man': True,
#   'love': False,
#   'star': False,
#   'try': False,
#   'director': False,
#   'great': True,
#   'never': False,
#   'performance': True,
#   'actor': True,
#   'new': False,
# ...

# %%
from nltk import NaiveBayesClassifier

# %%
classfier = NaiveBayesClassifier.train(training_data)

# %%
nltk.classify.accuracy(classfier, testing_data)
# Out:
# 0.8646666666666667

# %%
classfier.show_most_informative_features(30)
# Out:
# Most Informative Features
#                  idiotic = True              neg : pos    =     16.6 : 1.0
#                   seagal = True              neg : pos    =     11.4 : 1.0
#                stupidity = True              neg : pos    =      9.5 : 1.0
#              outstanding = True              pos : neg    =      8.5 : 1.0
#                ludicrous = True              neg : pos    =      7.9 : 1.0
#             breathtaking = True              pos : neg    =      7.5 : 1.0
#                     lame = True              neg : pos    =      7.1 : 1.0
#                    damon = True              pos : neg    =      6.6 : 1.0
#              wonderfully = True              pos : neg    =      6.6 : 1.0
#                  unfunny = True              neg : pos    =      6.6 : 1.0
#              beautifully = True              pos : neg    =      6.3 : 1.0
#                   alicia = True              neg : pos    =      6.0 : 1.0
# ...

# %%
from sklearn.svm import SVC

# %%
from nltk.classify.scikitlearn import SklearnClassifier

# %%
svc = SVC()
classfier_sklearn = SklearnClassifier(svc)

# %%
classifier = classfier_sklearn.train(training_data)

# %%
nltk.classify.accuracy(classifier,testing_data)
# Out:
# 0.9926666666666667

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest = RandomForestClassifier()
classifier_sklearn = SklearnClassifier(random_forest)

# %%
classifier1 = classifier_sklearn.train(training_data)

# %%
nltk.classify.accuracy(classifier1,testing_data)
# Out:
# 1.0
